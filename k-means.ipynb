# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
vitrina = pd.read_excel('vitrina.xlsx')

# %%
vitrina
# Out:
#                       Phone_new  Number of bills  Average bill  \
# 0            32565748-000000000                8      2469.625
# 1       32565750-575448565151 а                1     26599.000
# 2      32565750-575448565151 а5                1      1590.000
# 3      43553240-575054413251+75                2      5064.500
# 4      55445748-514957495657715                1     27449.000
# ...                         ...              ...           ...
# 88883   57495456-56485151574991                1      1609.000
# 88884   57505548-48535350504991                1       999.000
# 88885   57555656-55575253555698                1      3850.000
# 88886   57565352-52575050555092                1      1999.000
# 88887   57565355-57554952485597                1      3080.000
#
#        Average number of goods in bill  Revenue  Total quantity  Discount  \
# 0                                  1.0    19757               8         0
# 1                                  2.0    26599               2         0
# 2                                  1.0     1590               1         0
# 3                                  1.0    10129               2         0
# 4                                  1.0    27449               1         0
# ...                                ...      ...             ...       ...
# 88883                              1.0     1609               1         0
# 88884                              1.0      999               1         0
# 88885                              1.0     3850               1         0
# 88886                              1.0     1999               1       591
# 88887                              1.0     3080               1         0
#
#        Number of goods
# 0                    8
# 1                    2
# 2                    1
# 3                    2
# 4                    1
# ...                ...
# 88883                1
# 88884                1
# 88885                1
# 88886                1
# 88887                1
#
# [88888 rows x 8 columns]

# %%
vitrina.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88888 entries, 0 to 88887
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Phone_new                        88888 non-null  object
#  1   Number of bills                  88888 non-null  int64
#  2   Average bill                     88888 non-null  float64
#  3   Average number of goods in bill  88888 non-null  float64
#  4   Revenue                          88888 non-null  int64
#  5   Total quantity                   88888 non-null  int64
#  6   Discount                         88888 non-null  int64
#  7   Number of goods                  88888 non-null  int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 5.4+ MB

# %%
vitrina.sort_values(by = 'Number of bills', ascending = False)
# Out:
#                       Phone_new  Number of bills  Average bill  \
# 43339  55574954-484951565653705              984  13183.030488
# 959     55574850-51534848565673              307  15809.345277
# 42683   55574953-54565256525374              267   9782.985019
# 87034   55575653-56495057484877              114  20780.464912
# 6       55485656-57565656575275              111  12237.657658
# ...                         ...              ...           ...
# 30992   55574949-48575648525778                1   8399.000000
# 30991  55574949-485755575254715                1   6580.000000
# 30990   55574949-48575557525471                1   8072.000000
# 30989  55574949-485755565549795                1   6999.000000
# 88887   57565355-57554952485597                1   3080.000000
#
#        Average number of goods in bill   Revenue  Total quantity  Discount  \
# 43339                         1.066057  12972102            1058    255735
# 959                           1.048860   4853469             330     68816
# 42683                         1.022472   2612057             277     29486
# 87034                         1.008772   2368973             115     77800
# 6                             1.036036   1358380             115     21715
# ...                                ...       ...             ...       ...
# 30992                         1.000000      8399               1         0
# 30991                         1.000000      6580               1         0
# 30990                         1.000000      8072               1      1425
# 30989                         1.000000      6999               1         0
# 88887                         1.000000      3080               1         0
#
#        Number of goods
# 43339             1049
# 959                322
# 42683              273
# 87034              115
# 6                  115
# ...                ...
# 30992                1
# 30991                1
# 30990                1
# 30989                1
# 88887                1
#
# [88888 rows x 8 columns]

# %%
vitrina.describe().T
# Out:
#                                    count          mean           std  min  \
# Number of bills                  88888.0      1.176818      3.839387  1.0
# Average bill                     88888.0   9158.368995  11960.216391  1.0
# Average number of goods in bill  88888.0      1.132362      0.502620  1.0
# Revenue                          88888.0  11282.812011  54796.307937  1.0
# Total quantity                   88888.0      1.406545      4.285117  1.0
# Discount                         88888.0    216.454088   1425.183261  0.0
# Number of goods                  88888.0      1.338572      4.151465  1.0
#
#                                     25%     50%      75%         max
# Number of bills                     1.0     1.0      1.0       984.0
# Average bill                     2189.0  5410.0  11999.0    429990.0
# Average number of goods in bill     1.0     1.0      1.0        18.0
# Revenue                          2280.0  5659.5  12820.0  12972102.0
# Total quantity                      1.0     1.0      1.0      1058.0
# Discount                            0.0     0.0      0.0    255735.0
# Number of goods                     1.0     1.0      1.0      1049.0

# %%
vitrina.columns
# Out:
# Index(['Phone_new', 'Number of bills', 'Average bill',
#        'Average number of goods in bill', 'Revenue', 'Total quantity',
#        'Discount', 'Number of goods'],
#       dtype='object')

# %%
vitrina = vitrina.loc[1:,:]

# %%
#vitrina_per = vitrina.drop(columns = ['%TN_Автотовары',
 #      '%TN_Аксессуары', '%TN_Детские товары', '%TN_Игры, софт и развлечения',
#     '%TN_Климат', '%TN_Крупная бытовая техника', '%TN_Мебель',
 #      '%TN_Мелкая бытовая техника', '%TN_Сделай сам',
  #     '%TN_Спорт и активный отдых', '%TN_ТВ-Аудио', '%TN_Товары для дома',
   #    '%TN_Услуги', '%TN_Хобби, досуг', '%TN_Цифровая Техника',
    #   '%TN_Элитная техника'])
#vitrina_per

# %%
sns.set(rc = {'figure.figsize':(20,15)})
sns.heatmap(vitrina.corr(), annot=True, fmt=".2f", vmin=-1, vmax=1);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 sns.set(rc = {'figure.figsize':(20,15)})
# ----> 2 sns.heatmap(vitrina.corr(), annot=True, fmt=".2f", vmin=-1, vmax=1);
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/internals/managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/internals/managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: '32565750-575448565151 а'

# %%
vitrina_per = vitrina.drop(columns = ['Number of goods'])

# %%
vitrina_per = vitrina_per.drop(columns = ['Total quantity'])

# %%
from sklearn.cluster import KMeans

# %%
x = vitrina_per.drop(columns = ['Phone_new'])

# %%
ess = []
for k in range(2, 12):
    kmeans = KMeans(n_clusters=k, random_state=0, max_iter=100)
    kmeans.fit(x)
    ess.append(kmeans.inertia_)

plt.rcParams["figure.figsize"] = (10,5)
plt.plot(range(2, 12), ess)
plt.xticks(range(2, 12))
plt.show()
# Out:
# /Users/kamila/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/kamila/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/kamila/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/kamila/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/kamila/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/kamila/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/kamila/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/kamila/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/kamila/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/kamila/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
k = 5
kmeans = KMeans(n_clusters=k, random_state=0)
y = kmeans.fit_predict(x)
x
# Out:
# /Users/kamila/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#        Number of bills  Average bill  Average number of goods in bill  \
# 1                    1       26599.0                              2.0
# 2                    1        1590.0                              1.0
# 3                    2        5064.5                              1.0
# 4                    1       27449.0                              1.0
# 5                    1        2390.0                              1.0
# ...                ...           ...                              ...
# 88883                1        1609.0                              1.0
# 88884                1         999.0                              1.0
# 88885                1        3850.0                              1.0
# 88886                1        1999.0                              1.0
# 88887                1        3080.0                              1.0
#
#        Revenue  Discount
# 1        26599         0
# 2         1590         0
# 3        10129         0
# 4        27449         0
# 5         2390         0
# ...        ...       ...
# 88883     1609         0
# 88884      999         0
# 88885     3850         0
# 88886     1999       591
# 88887     3080         0
#
# [88887 rows x 5 columns]

# %%
df_kmeans = vitrina_per
df_kmeans['cluster'] = y
df_kmeans
# Out:
#                       Phone_new  Number of bills  Average bill  \
# 1       32565750-575448565151 а                1       26599.0
# 2      32565750-575448565151 а5                1        1590.0
# 3      43553240-575054413251+75                2        5064.5
# 4      55445748-514957495657715                1       27449.0
# 5      55485351-525749505548705                1        2390.0
# ...                         ...              ...           ...
# 88883   57495456-56485151574991                1        1609.0
# 88884   57505548-48535350504991                1         999.0
# 88885   57555656-55575253555698                1        3850.0
# 88886   57565352-52575050555092                1        1999.0
# 88887   57565355-57554952485597                1        3080.0
#
#        Average number of goods in bill  Revenue  Discount  cluster
# 1                                  2.0    26599         0        0
# 2                                  1.0     1590         0        2
# 3                                  1.0    10129         0        2
# 4                                  1.0    27449         0        0
# 5                                  1.0     2390         0        2
# ...                                ...      ...       ...      ...
# 88883                              1.0     1609         0        2
# 88884                              1.0      999         0        2
# 88885                              1.0     3850         0        2
# 88886                              1.0     1999       591        2
# 88887                              1.0     3080         0        2
#
# [88887 rows x 7 columns]

# %%
# Each cluster's fraction of the dataset
cluster_counts = np.array(df_kmeans['cluster'].value_counts().sort_index())
cluster_frac = cluster_counts/np.sum(cluster_counts)
cluster_frac
# Out:
# array([1.06134755e-01, 1.12502391e-05, 8.92537716e-01, 6.75014344e-05,
#        1.24877654e-03])

# %%
df_kmeans.groupby(by = 'cluster').median(numeric_only=True).round(3)
# Out:
#          Number of bills  Average bill  Average number of goods in bill  \
# cluster
# 0                    1.0     28714.250                            1.000
# 1                  984.0     13183.030                            1.066
# 2                    1.0      4520.000                            1.000
# 3                  108.5     18466.705                            1.083
# 4                   23.0     19200.682                            1.077
#
#             Revenue  Discount
# cluster
# 0           33399.0       0.0
# 1        12972102.0  255735.0
# 2            4799.0       0.0
# 3         2230968.0   50036.5
# 4          418657.0    7199.0

# %%
vitrina_vto = vitrina_per.drop(columns = ['Number of bills'])

# %%
xx = vitrina_vto.drop(columns = ['Phone_new'])

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
ess = []
for k in range(2, 12):
    kmeans = KMeans(n_clusters=k, random_state=0, max_iter=100)
    kmeans.fit(xx)
    ess.append(kmeans.inertia_)

plt.rcParams["figure.figsize"] = (10,5)
plt.plot(range(2, 12), ess)
plt.xticks(range(2, 12))
plt.show()

# %%
k = 5
kmeans = KMeans(n_clusters=k, random_state=0)
yy = kmeans.fit_predict(xx)
xx
# Out:
#        Average bill  Average number of goods in bill  Revenue  Discount  \
# 1           26599.0                              2.0    26599         0
# 2            1590.0                              1.0     1590         0
# 3            5064.5                              1.0    10129         0
# 4           27449.0                              1.0    27449         0
# 5            2390.0                              1.0     2390         0
# ...             ...                              ...      ...       ...
# 88883        1609.0                              1.0     1609         0
# 88884         999.0                              1.0      999         0
# 88885        3850.0                              1.0     3850         0
# 88886        1999.0                              1.0     1999       591
# 88887        3080.0                              1.0     3080         0
#
#        cluster
# 1            0
# 2            2
# 3            2
# 4            0
# 5            2
# ...        ...
# 88883        2
# 88884        2
# 88885        2
# 88886        2
# 88887        2
#
# [88887 rows x 5 columns]

# %%
df_kmeans_2 = vitrina_vto
df_kmeans_2['cluster'] = yy
df_kmeans_2
# Out:
#                       Phone_new  Average bill  \
# 1       32565750-575448565151 а       26599.0
# 2      32565750-575448565151 а5        1590.0
# 3      43553240-575054413251+75        5064.5
# 4      55445748-514957495657715       27449.0
# 5      55485351-525749505548705        2390.0
# ...                         ...           ...
# 88883   57495456-56485151574991        1609.0
# 88884   57505548-48535350504991         999.0
# 88885   57555656-55575253555698        3850.0
# 88886   57565352-52575050555092        1999.0
# 88887   57565355-57554952485597        3080.0
#
#        Average number of goods in bill  Revenue  Discount  cluster
# 1                                  2.0    26599         0        0
# 2                                  1.0     1590         0        2
# 3                                  1.0    10129         0        2
# 4                                  1.0    27449         0        0
# 5                                  1.0     2390         0        2
# ...                                ...      ...       ...      ...
# 88883                              1.0     1609         0        2
# 88884                              1.0      999         0        2
# 88885                              1.0     3850         0        2
# 88886                              1.0     1999       591        2
# 88887                              1.0     3080         0        2
#
# [88887 rows x 6 columns]

# %%
# Each cluster's fraction of the dataset
cluster_counts = np.array(df_kmeans_2['cluster'].value_counts().sort_index())
cluster_frac = cluster_counts/np.sum(cluster_counts)
cluster_frac
# Out:
# array([1.06134755e-01, 1.12502391e-05, 8.92537716e-01, 6.75014344e-05,
#        1.24877654e-03])

# %%
df_kmeans_2.groupby(by = 'cluster').median(numeric_only=True).round(3)
# Out:
#          Average bill  Average number of goods in bill     Revenue  Discount
# cluster
# 0           28714.250                            1.000     33399.0       0.0
# 1           13183.030                            1.066  12972102.0  255735.0
# 2            4520.000                            1.000      4799.0       0.0
# 3           18466.705                            1.083   2230968.0   50036.5
# 4           19200.682                            1.077    418657.0    7199.0

# %%
plt.pie(df_kmeans_2.cluster.value_counts(),
        labels=df_kmeans_2.cluster.value_counts().index,
        autopct='%.0f%%')
plt.show()

# %%
import datetime

# %%
#OrderDate = vitrina['OrderDate'].astype(np.datetime64)
#OrderDate

# %%
#OrderDate = OrderDate.astype(np.int64)
#OrderDate
# Out:
# 1        1459382400000000000
# 2        1460419200000000000
# 3        1460160000000000000
# 4        1461801600000000000
# 5        1460678400000000000
#                 ...
# 88883    1457913600000000000
# 88884    1457222400000000000
# 88885    1461024000000000000
# 88886    1456876800000000000
# 88887    1460246400000000000
# Name: OrderDate, Length: 88887, dtype: int64

# %%
#vitrina['OrderDate'] = OrderDate

# %%
rfm_df = vitrina[['Phone_new', 'Number of bills', 'Revenue']].dropna()

# %%
rfm_df.describe().T
# Out:
#                    count          mean           std  min     25%     50%  \
# Number of bills  88887.0      1.176741      3.839341  1.0     1.0     1.0
# Revenue          88887.0  11282.716674  54796.608803  1.0  2280.0  5659.0
#
#                      75%         max
# Number of bills      1.0       984.0
# Revenue          12820.0  12972102.0

# %%
rfm_df['F_rank'] = rfm_df['Number of bills'].rank(ascending=True)
rfm_df['M_rank'] = rfm_df['Revenue'].rank(ascending=True)

rfm_df['F_rank_norm'] = (rfm_df['F_rank']/rfm_df['F_rank'].max())*100
rfm_df['M_rank_norm'] = (rfm_df['M_rank']/rfm_df['M_rank'].max())*100

rfm_df.drop(columns=['F_rank', 'M_rank'], inplace=True)

rfm_df
# Out:
#                       Phone_new  Number of bills  Revenue  F_rank_norm  \
# 1       32565750-575448565151 а                1    26599    46.039916
# 2      32565750-575448565151 а5                1     1590    46.039916
# 3      43553240-575054413251+75                2    10129    95.085896
# 4      55445748-514957495657715                1    27449    46.039916
# 5      55485351-525749505548705                1     2390    46.039916
# ...                         ...              ...      ...          ...
# 88883   57495456-56485151574991                1     1609    46.039916
# 88884   57505548-48535350504991                1      999    46.039916
# 88885   57555656-55575253555698                1     3850    46.039916
# 88886   57565352-52575050555092                1     1999    46.039916
# 88887   57565355-57554952485597                1     3080    46.039916
#
#        M_rank_norm
# 1        91.691698
# 2        15.812211
# 3        68.476268
# 4        92.187834
# 5        26.065116
# ...            ...
# 88883    16.357285
# 88884     7.999482
# 88885    39.108081
# 88886    22.016155
# 88887    33.630902
#
# [88887 rows x 5 columns]

# %%
#rfm_df['RFM_Score'] = 0.15*rfm_df['R_rank_norm']+0.28 * \
#   rfm_df['F_rank_norm']+0.57*rfm_df['M_rank_norm']
#rfm_df['RFM_Score'] *= 0.05
#data_seg_RFM = rfm_df.round(2)

rfm_df['RFM_Score'] = 0.28*rfm_df['F_rank_norm']+0.57*rfm_df['M_rank_norm']
rfm_df['RFM_Score'] *= 0.05
data_seg_RFM = rfm_df.round(2)

# %%
rfm_df["Customer_segment"] = np.where(rfm_df['RFM_Score'] >
                                      4.5, "Top Customers",
                                      (np.where(
                                        rfm_df['RFM_Score'] > 4,
                                        "High value Customer",
                                        (np.where(
  rfm_df['RFM_Score'] > 3,
                             "Medium Value Customer",
                             np.where(rfm_df['RFM_Score'] > 1.6,
                            'Low Value Customers', 'Lost Customers'))))))
rfm_df[['RFM_Score', 'Customer_segment']].head(20)
# Out:
#     RFM_Score       Customer_segment
# 1    3.257772  Medium Value Customer
# 2    1.095207         Lost Customers
# 3    3.282776  Medium Value Customer
# 4    3.271912  Medium Value Customer
# 5    1.387415         Lost Customers
# 6    4.249713    High value Customer
# 7    1.141282         Lost Customers
# 8    1.790978    Low Value Customers
# 9    3.850230  Medium Value Customer
# 10   1.230417         Lost Customers
# 11   1.337220         Lost Customers
# 12   2.953567    Low Value Customers
# 13   2.351218    Low Value Customers
# 14   1.149169         Lost Customers
# 15   1.360417         Lost Customers
# 16   1.095207         Lost Customers
# 17   2.693220    Low Value Customers
# 18   0.896030         Lost Customers
# 19   1.225832         Lost Customers
# 20   1.998250    Low Value Customers

# %%
plt.pie(rfm_df.Customer_segment.value_counts(),
        labels=rfm_df.Customer_segment.value_counts().index,
        autopct='%.0f%%')
plt.show()

# %%
for i in ['Top Customers', 'High value Customer', 'Medium Value Customer', 'Low Value Customers', 'Lost Customers']:
  print(i)
  print(vitrina[rfm_df['Customer_segment'] == i].describe().T)
# Out:
# Top Customers
#                                  count  mean  std  min  25%  50%  75%  max
# Number of bills                    0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Average bill                       0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Average number of goods in bill    0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Revenue                            0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Total quantity                     0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Discount                           0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Number of goods                    0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# High value Customer
#                                   count           mean            std  \
# Number of bills                  1937.0       5.925658      25.475998
# Average bill                     1937.0   22090.140519   13119.993171
# Average number of goods in bill  1937.0       1.259992       0.636663
# Revenue                          1937.0  104726.838410  350168.240552
# Total quantity                   1937.0       7.191017      27.547886
# Discount                         1937.0    2122.442437    7889.366329
# Number of goods                  1937.0       6.881776      27.159803
#
#                                           min           25%      50%  \
# Number of bills                      2.000000      2.000000      2.0
# Average bill                      3144.111111  15223.333333  19109.5
# Average number of goods in bill      1.000000      1.000000      1.0
# Revenue                          26448.000000  38677.000000  52868.0
# Total quantity                       2.000000      2.000000      3.0
# Discount                             0.000000      0.000000      0.0
# Number of goods                      2.000000      2.000000      3.0
#
#                                           75%         max
# Number of bills                      4.000000       984.0
# Average bill                     26025.000000    169782.0
# Average number of goods in bill      1.333333        15.5
# Revenue                          89389.000000  12972102.0
# Total quantity                       6.000000      1058.0
# Discount                          1831.000000    255735.0
# Number of goods                      6.000000      1049.0
# Medium Value Customer
#                                    count          mean           std  \
# Number of bills                  15263.0      1.237830      0.569428
# Average bill                     15263.0  25835.932392  18870.383385
# Average number of goods in bill  15263.0      1.238071      0.702850
# Revenue                          15263.0  27444.478870  17704.705353
# Total quantity                   15263.0      1.639848      1.811979
# Discount                         15263.0    444.805019   1560.698145
# Number of goods                  15263.0      1.531285      1.156103
#
#                                          min      25%      50%      75%  \
# Number of bills                     1.000000      1.0      1.0      1.0
# Average bill                      862.727273  17290.0  22630.0  30490.0
# Average number of goods in bill     1.000000      1.0      1.0      1.0
# Revenue                          6799.000000  18480.0  23490.0  30579.5
# Total quantity                      1.000000      1.0      1.0      2.0
# Discount                            0.000000      0.0      0.0      0.0
# Number of goods                     1.000000      1.0      1.0      2.0
#
#                                       max
# Number of bills                      11.0
# Average bill                     429990.0
# Average number of goods in bill      17.0
# Revenue                          429990.0
# Total quantity                       57.0
# Discount                          40999.0
# Number of goods                      42.0
# Low Value Customers
#                                    count         mean          std  \
# Number of bills                  42570.0     1.054804     0.277545
# Average bill                     42570.0  7722.854625  3855.172288
# Average number of goods in bill  42570.0     1.132900     0.501258
# Revenue                          42570.0  7819.942636  3744.341594
# Total quantity                   42570.0     1.251280     0.910409
# Discount                         42570.0   164.016490   549.372870
# Number of goods                  42570.0     1.196876     0.629652
#
#                                         min     25%     50%      75%      max
# Number of bills                    1.000000     1.0     1.0      1.0     11.0
# Average bill                     164.222222  4710.0  6730.0  10590.0  16680.0
# Average number of goods in bill    1.000000     1.0     1.0      1.0     18.0
# Revenue                          995.000000  4830.0  6769.0  10590.0  16680.0
# Total quantity                     1.000000     1.0     1.0      1.0     38.0
# Discount                           0.000000     0.0     0.0      0.0   9491.0
# Number of goods                    1.000000     1.0     1.0      1.0     18.0
# Lost Customers
#                                    count         mean         std  min    25%  \
# Number of bills                  29117.0     1.007075    0.096750  1.0    1.0
# Average bill                     29117.0  1654.781534  787.224767  1.0  999.0
# Average number of goods in bill  29117.0     1.067678    0.326893  1.0    1.0
# Revenue                          29117.0  1657.138854  784.063370  1.0  999.0
# Total quantity                   29117.0     1.126215    0.542441  1.0    1.0
# Discount                         29117.0    46.631143  205.521435  0.0    0.0
# Number of goods                  29117.0     1.075729    0.349966  1.0    1.0
#
#                                     50%     75%     max
# Number of bills                     1.0     1.0     5.0
# Average bill                     1630.0  2280.0  3060.0
# Average number of goods in bill     1.0     1.0     9.0
# Revenue                          1630.0  2280.0  3060.0
# Total quantity                      1.0     1.0    21.0
# Discount                            0.0     0.0  2799.0
# Number of goods                     1.0     1.0     9.0

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster import hierarchy

# %%
import matplotlib.pyplot as plt

# %%
#import scipy.cluster.hierarchy as shc

#plt.figure(figsize=(10, 7))
#plt.title("Customer Dendograms")
#dend = shc.dendrogram(shc.linkage(vitrina_vto, method='ward'))

# %%
hierarch_cluster = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')
hierarch_cluster.fit_predict(xx)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
